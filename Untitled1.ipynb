# %%
dataset_file = "english_speech_2.txt"
dataset_2 =  "sample_code.txt"

# %%
## Markov Chains

def load_text(filename):
    with open(filename,encoding='utf8') as f:
        return f.read().lower()
    
text = load_text(dataset_2)

# %%
print(text[:50])
# Out:
# #!/usr/bin/env python
# # coding: utf-8
#
# # in[122]:

# %%
# From the dataset you want generate some X and Y pairs
# X is the sequence of 'K = 3' and Y is predicted character or K+1 the character

the_?
X      Y     Freq
the    " "    4
the    "n"    2
the    "y"    1
the    "i"    1
dea    "r"    1
# Out:
#   File "<ipython-input-127-f33c5a8afb6a>", line 5
#     X      Y     Freq
#            ^
# SyntaxError: invalid syntax

# %%
d = {
    "the":{" ":4,"n":2,"i":1},
    "dea":{"r":1}
}

# %%
d["the"]["n"]
# Out:
# 2

# %%
def generateTable(data,k=4):
    T = {}
    for i in range(len(data)-k):
        X = data[i:i+k]
        Y = data[i+k]
        
        if T.get(X) is None:
            T[X] = {}
            T[X][Y] = 1
        else:
            if T[X].get(Y) is None:
                T[X][Y] =1
            else:
                T[X][Y] += 1
    return T

# %%
T = generateTable("Hello Hello World Helli")
generateTable("Hello Hello World Helli")
# Out:
# {'Hell': {'o': 2, 'i': 1},
#  'ello': {' ': 2},
#  'llo ': {'H': 1, 'W': 1},
#  'lo H': {'e': 1},
#  'o He': {'l': 1},
#  ' Hel': {'l': 2},
#  'lo W': {'o': 1},
#  'o Wo': {'r': 1},
#  ' Wor': {'l': 1},
#  'Worl': {'d': 1},
#  'orld': {' ': 1},
#  'rld ': {'H': 1},
#  'ld H': {'e': 1},
#  'd He': {'l': 1}}

# %%
def convertFreqIntoProb(T):
    for kx in T.keys():
        s = float(sum(T[kx].values()))
        for k in T[kx].keys():
            T[kx][k] = T[kx][k]/s
    
    return T

# %%
convertFreqIntoProb(T)
# Out:
# {'Hell': {'o': 0.6666666666666666, 'i': 0.3333333333333333},
#  'ello': {' ': 1.0},
#  'llo ': {'H': 0.5, 'W': 0.5},
#  'lo H': {'e': 1.0},
#  'o He': {'l': 1.0},
#  ' Hel': {'l': 1.0},
#  'lo W': {'o': 1.0},
#  'o Wo': {'r': 1.0},
#  ' Wor': {'l': 1.0},
#  'Worl': {'d': 1.0},
#  'orld': {' ': 1.0},
#  'rld ': {'H': 1.0},
#  'ld H': {'e': 1.0},
#  'd He': {'l': 1.0}}

# %%
def train(data,k):
    T = generateTable(data,k)
    T = convertFreqIntoProb(T)
    return T

# %%
T = train(text,4)

# %%
print(T)
# Out:
# {'#!/u': {'s': 1.0}, '!/us': {'r': 1.0}, '/usr': {'/': 1.0}, 'usr/': {'b': 1.0}, 'sr/b': {'i': 1.0}, 'r/bi': {'n': 1.0}, '/bin': {'/': 1.0}, 'bin/': {'e': 1.0}, 'in/e': {'n': 1.0}, 'n/en': {'v': 1.0}, '/env': {' ': 1.0}, 'env ': {'p': 1.0}, 'nv p': {'y': 1.0}, 'v py': {'t': 1.0}, ' pyt': {'h': 1.0}, 'pyth': {'o': 1.0}, 'ytho': {'n': 1.0}, 'thon': {'\n': 0.5, '(': 0.5}, 'hon\n': {'#': 1.0}, 'on\n#': {' ': 1.0}, 'n\n# ': {'c': 1.0}, '\n# c': {'o': 1.0}, '# co': {'d': 1.0}, ' cod': {'i': 1.0}, 'codi': {'n': 1.0}, 'odin': {'g': 1.0}, 'ding': {':': 0.5, '=': 0.5}, 'ing:': {' ': 1.0}, 'ng: ': {'u': 1.0}, 'g: u': {'t': 1.0}, ': ut': {'f': 1.0}, ' utf': {'-': 1.0}, 'utf-': {'8': 1.0}, 'tf-8': {'\n': 1.0}, 'f-8\n': {'\n': 1.0}, '-8\n\n': {'#': 1.0}, '8\n\n#': {' ': 1.0}, '\n\n# ': {'i': 0.95, 'f': 0.05}, '\n# i': {'n': 1.0}, '# in': {'[': 1.0}, ' in[': {'1': 0.3157894736842105, ' ': 0.05263157894736842, '2': 0.10526315789473684, '3': 0.05263157894736842, '5': 0.10526315789473684, '6': 0.15789473684210525, '8': 0.10526315789473684, '7': 0.05263157894736842, '9': 0.05263157894736842}, 'in[1': {'2': 0.5, '5': 0.16666666666666666, '0': 0.16666666666666666, '1': 0.16666666666666666}, 'n[12': {'2': 0.3333333333333333, '3': 0.3333333333333333, '1': 0.3333333333333333}, '[122': {']': 1.0}, '122]': {':': 1.0}, '22]:': {'\n': 1.0}, '2]:\n': {'\n': 1.0}, ']:\n\n': {'\n': 1.0}, ':\n\n\n': {'d': 0.42105263157894735, '#': 0.10526315789473684, 'p': 0.10526315789473684, 't': 0.10526315789473684, 'c': 0.05263157894736842, 'w': 0.05263157894736842, 'f': 0.05263157894736842, 's': 0.05263157894736842, 'g': 0.05263157894736842}, '\n\n\nd': {'a': 0.125, ' ': 0.125, '[': 0.125, 'e': 0.625}, '\n\nda': {'t': 1.0}, '\ndat': {'a': 1.0}, 'data': {'s': 0.4, ',': 0.3, ')': 0.1, '[': 0.2}, 'atas': {'e': 1.0}, 'tase': {'t': 1.0}, 'aset': {'_': 0.75, ' ': 0.25}, 'set_': {'f': 0.6666666666666666, '2': 0.3333333333333333}, 'et_f': {'i': 1.0}, 't_fi': {'l': 1.0}, '_fil': {'e': 1.0}, 'file': {' ': 0.25, 'n': 0.5, ')': 0.25}, 'ile ': {'=': 1.0}, 'le =': {' ': 1.0}, 'e = ': {'"': 0.5, 's': 0.5}, ' = "': {'e': 0.5, 'd': 0.5}, '= "e': {'n': 1.0}, ' "en': {'g': 1.0}, '"eng': {'l': 1.0}, 'engl': {'i': 1.0}, 'ngli': {'s': 1.0}, 'glis': {'h': 1.0}, 'lish': {'_': 1.0}, 'ish_': {'s': 1.0}, 'sh_s': {'p': 1.0}, 'h_sp': {'e': 1.0}, '_spe': {'e': 1.0}, 'spee': {'c': 1.0}, 'peec': {'h': 1.0}, 'eech': {'_': 1.0}, 'ech_': {'2': 1.0}, 'ch_2': {'.': 1.0}, 'h_2.': {'t': 1.0}, '_2.t': {'x': 1.0}, '2.tx': {'t': 1.0}, '.txt': {'"': 1.0}, 'txt"': {'\n': 1.0}, 'xt"\n': {'#': 1.0}, 't"\n#': {'d': 1.0}, '"\n#d': {'a': 1.0}, '\n#da': {'t': 1.0}, '#dat': {'a': 1.0}, 'et_2': {' ': 1.0}, 't_2 ': {'=': 1.0}, '_2 =': {' ': 1.0}, '2 = ': {'"': 1.0}, '= "d': {'t': 1.0}, ' "dt': {'u': 1.0}, '"dtu': {'"': 1.0}, 'dtu"': {'\n': 1.0}, 'tu"\n': {'\n': 1.0}, 'u"\n\n': {'\n': 1.0}, '"\n\n\n': {'#': 1.0}, '\n\n\n#': {' ': 0.95, '#': 0.05}, '[123': {']': 1.0}, '123]': {':': 1.0}, '23]:': {'\n': 1.0}, '3]:\n': {'\n': 1.0}, '\n\n##': {' ': 1.0}, '\n## ': {'m': 1.0}, '## m': {'a': 1.0}, '# ma': {'r': 1.0}, ' mar': {'k': 1.0}, 'mark': {'o': 1.0}, 'arko': {'v': 1.0}, 'rkov': {' ': 1.0}, 'kov ': {'c': 1.0}, 'ov c': {'h': 1.0}, 'v ch': {'a': 1.0}, ' cha': {'i': 0.3333333333333333, 'r': 0.6666666666666666}, 'chai': {'n': 1.0}, 'hain': {'s': 1.0}, 'ains': {'\n': 1.0}, 'ins\n': {'\n': 1.0}, 'ns\n\n': {'d': 1.0}, 's\n\nd': {'e': 1.0}, '\n\nde': {'f': 1.0}, '\ndef': {' ': 1.0}, 'def ': {'l': 0.16666666666666666, 'g': 0.3333333333333333, 'c': 0.16666666666666666, 't': 0.16666666666666666, 's': 0.16666666666666666}, 'ef l': {'o': 1.0}, 'f lo': {'a': 1.0}, ' loa': {'d': 1.0}, 'load': {'_': 1.0}, 'oad_': {'t': 1.0}, 'ad_t': {'e': 1.0}, 'd_te': {'x': 1.0}, '_tex': {'t': 1.0}, 'text': {'(': 0.5714285714285714, ' ': 0.14285714285714285, '[': 0.14285714285714285, ',': 0.14285714285714285}, 'ext(': {'f': 0.14285714285714285, 'd': 0.14285714285714285, 'c': 0.2857142857142857, '"': 0.2857142857142857, 's': 0.14285714285714285}, 'xt(f': {' ...

# %%
words = ["apple","mango","banana"]
prob = [.2,.6,.2]

import numpy as np

# %%
for i in range(10):
    print(np.random.choice(words,p=prob))
# Out:
# apple
# banana
# apple
# banana
# banana
# mango
# mango
# apple
# mango
# mango

# %%
def sample_next(ctx,T):
    
    ctx = ctx[-4:]
    if T.get(ctx) is None:
        return " "
    possible_chars = list(T[ctx].keys())
    possible_values = list(T[ctx].values())
    #print(possible_chars)
    #print(possible_values)
    
    return np.random.choice(possible_chars,p=possible_values)

# %%
sample_next("any ",T)
# Out:
# '"'

# %%
def generateText(starting_sent,maxLen=10000):
    #np.random.seed(1)
    sentence = starting_sent
    ctx = starting_sent[-4:]
    
    for ix in range(maxLen):
        next_prediction = sample_next(ctx,T)
        sentence += next_prediction
        ctx = sentence[-4:]
    
    return sentence

# %%
print(generateText("print"))
# Out:
# print(t)
#
#
# # in[99]:
#
#
# data[i+k]
#
#
#
#     return " "
#     "r"     1
#
#
# # in[60]:
#
#
# def train(text(starting_sent
#
#
#
# # in[121]:
#
#
# def load_text("any ",t)
#     #print(possible_values)
#        "y"     t[x][y] =1
#     sentence[-4:]
#       "i"     return t
#     for k+1 the chars)
#     return sentence[-4:]
#
#
#
# # in[ ]:
#
#
# d = {}
#     1
# dea       #np.random.choice(words,p=possible_chars)
#     if t.get(y) is none:
#     t[x] = {}
#        "n"              #np.random.seed(1)
#          t[kx].keys():
#        return t
#      1
# the      t = ctx = sample_next_prediction = starting_sentence of 'k = 3' and y is none:
#      freqintoprob(t)
#     "the"]["n"]
#
#
# # in[80]:
#
#
# def generatetext = generate some x and y pairs
# # x is none:
#      "n"    t[x][y] += next_predicted chars = [.2,.6,.2]
#
# import numpy as np
#
#
# # in[21]:
#
#
# sample_next_prediction
#        sent
#       y = data[i+k]
#      ctx = convertfreqintoprob(t)
#
#
# # in[21]:
#
#
# dataset you want generatetable(dataset you want generatetable(data[i+k]
#     sentence[-4:]
#     #print(possible_character or k+1 the    return " "
#
#        y = dataset you want generatetext(file = "english_speech_2.txt"
# #data)-k):
#     #print(text = ctx[-4:]
#         freqintoprob))
#
#
# ## markov chars,p=prob(t):
#      t = {
#
# text,4)
#
#
# # in[21]:
#
#
# data,k=4):
#       t[x][y] += 1
#       possible_chars)
#     with open(filename,encoding='utf8') as f:
#      y       for ix in t.keys():
#     1
# dea      1
# the
#      if t.get(y) is predicted chars)
#      ctx = dataset you want generatetext = {
#      y       t = ctx = convertfreqintoprob(t)
#
#
# # in[122]:
#
#
# t = generatetable(data,k=4):
#
#
#
# # in[88]:
#
#
# def load_text[:50])
#
#
# # in[52]:
#
#
# print(possible_chars)
#         for ix in range(10):
#     s = list(t[ctx].values())
#      "n"       t[x][y] = {}
#
#     else:
#
#
#
# # in[59]:
#
#
# print(np.random.choice(words = load_text[:50])
#
#
# # in[52]:
#
#
# print(np.random.choice(possible_values())
#       possible_chars = ["apple","mango","banana"]
# prob(t)
#
# text("any ",t)
#              "n"               1
# the sequence of 'k = 3' and y pairs
# # x is prediction = starting_sentence of 'k = 3' and y is none:
#     for kx in t.keys())
#     " "
#        t = generatetext = generatetable(data,k)
#
#
#
# # in[121]:
#
#
# # in[31]:
#
#
# for i in range(maxlen=100):
#     1
# the       for i in range(len(data)-k):
#     return t
#
#
#
# # in[52]:
#
#
# def sample_next("the":{"r":1},
#
#      "y"
#
#
# # in[103]:
#
#
# data,k=4):
#     1
#
#
# # in[122]:
#
#
# def sample_next_predicted chains
#
# def sample_next(ctx) is none:
#      ctx = sample_next("any ",t)
#      #print(np.random.choice(possible_values)
#       ctx = convertfreq
# the sequence
#
#
# # from the chars = [.2,.6,.2]
#
# import numpy as np
#
#
# # in[123]:
#
#
# def train(data)-k):
#       t = generate some x and y pairs
# # x is none:
#       "dea":{"r":1},
#       print(np.random.choice(possible_values)
#      #print(possible_values())
#      1
# the data[i:i+k]
#     "dea":{"r":1},
#     1
# dea
#
#
# # from the chars = ["apple","mango","banana"]
# prob = ["apple","mango","banana"]
# prob))
#
#
# # in[52]:
#
#
# t = generatetable("hello world hello world helli")
#
#
# # in[122]:
#
#
# print(text,4)
#
#
# # in[52]:
#
#
# print(np.random.choice(words = list(t[ctx].keys())
#        "n"        return t
#
#
#
# # in[121]:
#
#
# print(np.random.choice(possible_values())
#     ctx = starting_sent,maxlen):
#             t = train(text(file)
#
#
# # in[121]:
#
#
# get_ipython().run_line_magic('pinfo', 'the_')
# x      y    2
# the
#
#
# # in[60]:
#
#
# # in[59]:
#
#
# data[i+k]
#        4
# the    for i in t[kx].values)
#
#        t = list(t[ctx].values = float(sum(t[kx][k]/s
#
#
#
#
# # in[80]:
#
#
# # in[119]:
#
#
# # in[60]:
#
#
# sample_next_predicted character
#
# get_ipython().run_line_magic('pinfo', 'the_')
# x        next(ctx) is prediction
#       1
#
#
# # in[122]:
#
#
# print(np.random.choice(possible_values)
#      if t[x][y] += next_predicted chains
#
# def generatetext,4)
#
#
# # in[123]:
#
#
# def load_text(starting_sent,maxlen=100):
#            ctx = starting_sent
#      next(ctx,t):
#         4
# the sequence of 'k = 3' and y pairs
# # x is the sequence of 'k = 3' and y is none:
#        t[x][y] =1
#        y = data[i:i+k]
#        4
# the       if t.get(ctx) is none:
#
#
#
# # in[80]:
#
#
# def sample_next_prediction = sample_next_predicted chains
#
# def sample_next_prediction
#
#
#
# # in[59]:
#
#
# def generatetable("hello world helli")
#
#
# # in[63]:
#
#
# def convertfreqintoprob = ["apple","mango","banana"]
# prob = [.2,.6,.2]
#
# import numpy as f:
#       t = t[kx].values)
#
#       y        return sentence = sent
#     with open(filename,encoding='utf8') as np
#
#
# # from the         for i in range(10):
#        2
# the dataset_2 = "dtu"
#
#
# # in[103]:
#
#
# def sample_next_predicted chars,p=possible_values)
#        for kx in range(maxlen):
#      else:
#       return " "
#
#
#
# # in[79]:
#
#
# d = {}
#      1
# the    for k+1 the sequence
#
#
# # in[123]:
#
#
# def generate some x and y pairs
# # x is none:
#       if t.get(y) is none:
#         print(text,4)
#
#
# # in[52]:
#
#
# def load_text(file = sample_next("any ",t)
#     return " "
#        for ix in range(maxlen):
#     for k in range(10):
#
#         for k in range(maxlen):
#              possible_character or k in range(len(data)-k):
#       t = list(t[ctx].values = float(sum(t[kx][k]/s
#        sentence[-4:]
#     4
# the chars = float(sum(t[kx][k]/s
#      t[x][y] = 1
#      t = generatetable(data[i+k]
#       4
# the    return t
#         with open(file)
#
#
# # in[99]:
#
#
# convertfreqintoprob(t)
#
#
# # in[20]:
#
#
# # from the     next_predicted chains
#
# def convertfreqintoprob(t)
#
#
# # in[88]:
#
#
# def sample_next(file = "english_speech_2.txt"
# #dataset you want generatetable("hello world hello world hello world hello helli")
#
#
# # in[31]:
#
#
# data,k=4):
#
#
#
# # in[52]:
#
#
# sample_next_prediction = sample_next("any ",t)
#
#
# # in[122]:
#
#
# generatetext[:50])
#
#
# # in[15]:
#
#
# convertfreqintoprob(t)
#
#
# # in[79]:
#
#
# def generate some x and y pairs
# # x is none:
#     ctx = sentence of 'k = 3' and y pairs
# # x is predicted chars = list(t[ctx].values())
#     "r"            if t.get(y) is the     "y"      print(possible_values = [.2,.6,.2]
#
# import numpy as f:
#
#        return t
#        t[x].get(x) is none:
#        t = train(dataset you want generatetable("hello hello hello hello world helli")
#
#
# # in[59]:
#
#
# d = {}
#       "then")
#
#
# # in[59]:
#
#
# # in[122]:
#
#
# def load_text[:50])
#
#
# # in[31]:
#
#
# t = {}
#       return sentence[-4:]
#     freqintoprob(t)
#
#
# # in[119]:
#
#
# d = {}
#      1
#
#
# # in[80]:
#
#
# # in[121]:
#
#
# generatetable(dataset_2 = "english_speech_2.txt"
# #data,k)
#          for k in range(len(data,k=4):
#
#          x = dataset you want generatetable(dataset_filename):
#          return t
#         "r"      "i"    y
#      freq
# the    t = generate some x and y is none:
#
#
#
# # from the     " "       else:
#
#
#
# # in[ ]:
#
#
# words = ["apple","mango","banana"]
# prob(t):
#           possible_chars)
#     "dea":{" ":4,"n":2,"i":1},
#      "r"
#     t[x] = train(data[i+k]
#     t[x][y] += next_prediction
#         for k in t.keys():
#      possible_chars,p=prob(t)
#          for ix in t[kx].keys():
#
#         if t[x][y] = {}
#              y    1
#
#
# # in[21]:
#
#
# ## markov chains
#
# def load_text(ctx,t)
#       return f.read().lower()
#
#          if t.get(x) is none:
#
#        t = list(t[ctx].values)
#        4
# the
#
#
# # in[60]:
#
#
# d["the":{" ":4,"n":2,"i":1}
# }
#
#
# # in[20]:
#
#
# # in[52]:
#
#
# sample_next_prediction
#          for i in t.keys():
#     t = generatetable("hello hello world hello helli")
# generatetext(ctx,t)
#
#
# # in[80]:
#
#
# data[i:i+k]
#     return np.random.seed(1)
#     " "     4
# the    #print(possible_values)
#        y    " "
#          for ix in t[kx].keys())
#       "the"]["n"]
#
#
# # in[60]:
#
#
# t = generatetable(data)-k):
#       return np.random.choice(possible_chars = float(sum(t[kx][k]/s
#      else:
#      else:
#      t[x] = {
#      y = data,k):
#
#      possible_values = list(t[ctx].values = float(sum(t[kx][k] = {
#       return t
#     return t
#     2
# the      #print(t)
#
#
# # in[123]:
#
#
# print(possible_chars = [.2,.6,.2]
#
# import numpy as f:
#      t[x][y] += next("any ",t)
#        1
# dea     t = ctx[-4:]
#          if t.get(ctx,t):
#
#       1
# the      for i in range(maxlen):
#
#        t[x][y] = {
#     next("any ",t)
#
#
# # in[122]:
#
#
# # in[80]:
#
#
# def generatetable(data,k)
#           #np.random.choice(words = float(sum(t[kx][k] = {}
#     2
# the
#
#
# # in[119]:
#
#
# sample_next_predicted chains
#
# def sample_next(filename):
#      return " "          return f.read().lower()
#       "y"       else:
#     return np.random.choice(words,p=prob(t):
#     1
#
#
# # in[59]:
#
#
# convertfreq
# the chars = list(t[ctx].keys())
#       ctx = convertfreqintoprob(t):
#      #print(possible_character
#
# generatetable("hello world hello world hello world hello world hello helli")
#
#
# # in[ ]:
#
#
# t = ctx = ctx = starting_sent[-4:]
#      "dea":{" ":4,"n":2,"i":1},
#
# text(ctx,t):
#
#      #print(possible_values = load_text("any ",t)
#
#
# # in[52]:
#
#
# # in[99]:
#
#
# t = convertfreq
# the    s = ["apple","mango","banana"]
# prob = [.2,.6,.2]
#
# import numpy as np
#
#
# # in[59]:
#
#
# words = load_text,4)
#
#
# ## markov chars,p=prob(t)
#
#
# # in[15]:
#
#
# dataset_2 = "dtu"
#
#
# # in[80]:
#
#
# def convertfreqintoprob = ["apple","mango","banana"]
# prob(t)
#            #print(text = ctx = convertfreq
# the dataset_filename,encoding='utf8') as f:
#
#          t = {}
#     return sent
#      if t[x][y] = {}
#     t[x].get(y) is none:
#
#     #np.random.choice(possible_values)
#      t[x] = 1
#          for k in t[kx][k] = 1
#     y = data,k)
#      #print(t)
#      else:
#        return t
#     #print(text(dataset_filename,encoding: utf-8
#
# # in[21]:
#
#
# def generatetable(data)-k):
#      2
# the     t = train(data,k):
#
# text(ctx,t):
#         y        sent[-4:]
#
#
#
# # in[103]:
#
#
# t = t[kx].values())
#     t[x].get(ctx) is the      t = ctx = starting_sentence of 'k = 3' and y is none:
#           "dea":{"r":1}
# }
#
#
# # in[80]:
#
#
# convertfreqintoprob(t)
#        "y"      return np.random.seed(1)
#     if t[x].get(ctx,t):
#     1
# dea            x = sample_next(ctx,t):
#
#
#
# # in[61]:
#
#
# t = generatetext(data,k)
#
#     s = float(sum(t[kx].keys()))
#        t = generatetable("hello hello world hello hello hello world helli")
# generate some x and y pairs
# # x is none:
#      for kx i

# %%
# Keras Library
# Numpy
# Matplotlib
# Pandas

# %%
## cb.lk/mldtu19

# %%
Neural Networks by 3 Blue and 1 Brown
What is a Neural Network?
How does it work!

Recommended-
Gradient Descent by Prateek Narang - http://cb.lk/yt
# Out:
#   File "<ipython-input-146-2b800c58c1d5>", line 1
#     Neural Networks by 3 Blue and 1 Brown
#                   ^
# SyntaxError: invalid syntax
